# %% [markdown]
# <a href="https://colab.research.google.com/github/Malith-19/ML-Project-1/blob/main/ML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Load the data.

# %%
import pandas as pd
from google.colab import drive, files

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_data = pd.read_csv('/content/drive/MyDrive/ML/Project/train.csv')
train_data.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0   0.186257  -0.058807   0.024632  -0.163933  -0.146699   0.035889
# 1   0.063431  -0.023597   0.068057  -0.252915  -0.061094  -0.027316
# 2   0.034962   0.035816  -0.029753  -0.094607  -0.017576  -0.053074
# 3   0.033772   0.085612   0.067488  -0.073953  -0.180646  -0.024512
# 4   0.134305   0.062096   0.106920  -0.089327   0.117093  -0.077107
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_763  feature_764  \
# 0   0.111708  -0.162861   0.028249   -0.098063  ...     0.055629    -0.010358
# 1   0.135747  -0.168147   0.091236   -0.078473  ...    -0.014893     0.071721
# 2   0.040121  -0.007932   0.097872   -0.024042  ...     0.012415     0.015215
# 3   0.242879  -0.023374  -0.059999    0.002006  ...    -0.078246    -0.032903
# 4   0.152579   0.047529  -0.015998   -0.110657  ...    -0.094629     0.069718
#
#    feature_765  feature_766  feature_767  feature_768  label_1  label_2  \
# ...

# %%
train_data.shape
# Out:
# (28520, 772)

# %%
test_data = pd.read_csv('/content/drive/MyDrive/ML/Project/train.csv')
test_data.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0   0.186257  -0.058807   0.024632  -0.163933  -0.146699   0.035889
# 1   0.063431  -0.023597   0.068057  -0.252915  -0.061094  -0.027316
# 2   0.034962   0.035816  -0.029753  -0.094607  -0.017576  -0.053074
# 3   0.033772   0.085612   0.067488  -0.073953  -0.180646  -0.024512
# 4   0.134305   0.062096   0.106920  -0.089327   0.117093  -0.077107
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_763  feature_764  \
# 0   0.111708  -0.162861   0.028249   -0.098063  ...     0.055629    -0.010358
# 1   0.135747  -0.168147   0.091236   -0.078473  ...    -0.014893     0.071721
# 2   0.040121  -0.007932   0.097872   -0.024042  ...     0.012415     0.015215
# 3   0.242879  -0.023374  -0.059999    0.002006  ...    -0.078246    -0.032903
# 4   0.152579   0.047529  -0.015998   -0.110657  ...    -0.094629     0.069718
#
#    feature_765  feature_766  feature_767  feature_768  label_1  label_2  \
# ...

# %% [markdown]
# ### Checking for null values in the train data set.

# %%
train_data.isnull().sum()
# Out:
# feature_1        0
# feature_2        0
# feature_3        0
# feature_4        0
# feature_5        0
#               ...
# feature_768      0
# label_1          0
# label_2        480
# label_3          0
# label_4          0
# Length: 772, dtype: int64

# %% [markdown]
# ### Dropping the data in train data set for missing values.

# %%
train_data = train_data.dropna()
train_data.isnull().sum()
# Out:
# feature_1      0
# feature_2      0
# feature_3      0
# feature_4      0
# feature_5      0
#               ..
# feature_768    0
# label_1        0
# label_2        0
# label_3        0
# label_4        0
# Length: 772, dtype: int64

# %%
train_data.shape
# Out:
# (28040, 772)
